# %%
# Imports
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from keras.applications.vgg16 import VGG16
from keras.layers import Flatten, Dense, Dropout
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.optimizers import Adam
from keras.utils import to_categorical, plot_model
from keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from keras.layers import GlobalMaxPooling2D, MaxPooling2D
from keras.layers import BatchNormalization

# %%
# Verify the version tensorflow
print(tf.__version__)
# Out:
# 2.15.0

# %%
# Loading the dataset
Cifar10 = keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = Cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
# Defining the label classes in the dataset
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %%
# не обовязковий параметр
# Inspect the data in the array
index = 0
plt.imshow(x_train[index], cmap=plt.cm.binary)
plt.colorbar()
plt.show()
print("Class ID: %s and Class name: %s" % (y_train[index], class_names[y_train[index][0]]))
# Out:
# Class ID: [6] and Class name: Frog

# %%
# Verify the data by display the first 25 images from traing set
plt.figure(figsize=(10, 10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(x_train[i], cmap=plt.cm.binary)
  plt.xlabel("ID: %s, name: %s" % (y_train[i], class_names[y_train[i][0]]))
plt.show()

# %%
# Pixel value of the image normalizing between 0 to 255
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = np.array(x_train) / 255.0
x_test = np.array(x_test) / 255.0

# %%
# One hot encoding of the labels
num_classes = 10
y_train=to_categorical(y_train, num_classes)
y_test=to_categorical(y_test, num_classes)

# %%
# Define the Convolutional Neural Network
conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
conv_base.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
# model
model = Sequential()
model.add(conv_base)
model.add(Flatten())
model.add(Dense(512, activation='relu', name='hidden_1'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu', name='hidden_2'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax', name='predictions'))

# %%
# Plot model graph
plot_model(model, 'model.png')

# %%
# Compile the model
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model with an EarlyStopping and ModelCheckpoint callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

filepath = "weights.h5"
model_checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', save_best_only=True, mode='max')

callbacks_list = [early_stopping, model_checkpoint]

# %%
# Training model
history = model.fit(
    x_train, y_train, epochs=100, verbose=1, batch_size=128, validation_split=0.2, callbacks=callbacks_list
)
# Out:
# Epoch 1/100
# 313/313 [==============================] - 15s 28ms/step - loss: 1.4592 - accuracy: 0.4847 - val_loss: 1.2453 - val_accuracy: 0.5619
# Epoch 2/100
#   1/313 [..............................] - ETA: 5s - loss: 1.3620 - accuracy: 0.4922
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 313/313 [==============================] - 6s 20ms/step - loss: 1.2304 - accuracy: 0.5662 - val_loss: 1.1858 - val_accuracy: 0.5829
# Epoch 3/100
# 313/313 [==============================] - 6s 20ms/step - loss: 1.1550 - accuracy: 0.5933 - val_loss: 1.1615 - val_accuracy: 0.5892
# Epoch 4/100
# 313/313 [==============================] - 6s 20ms/step - loss: 1.0993 - accuracy: 0.6136 - val_loss: 1.1378 - val_accuracy: 0.6008
# Epoch 5/100
# 313/313 [==============================] - 6s 20ms/step - loss: 1.0618 - accuracy: 0.6283 - val_loss: 1.1236 - val_accuracy: 0.6036
# Epoch 6/100
# 313/313 [==============================] - 6s 20ms/step - loss: 1.0184 - accuracy: 0.6427 - val_loss: 1.1050 - val_accuracy: 0.6178
# Epoch 7/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.9876 - accuracy: 0.6520 - val_loss: 1.1062 - val_accuracy: 0.6190
# Epoch 8/100
# 313/313 [==============================] - 6s 21ms/step - loss: 0.9544 - accuracy: 0.6658 - val_loss: 1.0968 - val_accuracy: 0.6231
# Epoch 9/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.9211 - accuracy: 0.6755 - val_loss: 1.1068 - val_accuracy: 0.6248
# Epoch 10/100
# 313/313 [==============================] - 7s 21ms/step - loss: 0.8962 - accuracy: 0.6824 - val_loss: 1.0934 - val_accuracy: 0.6259
# Epoch 11/100
# 313/313 [==============================] - 7s 21ms/step - loss: 0.8641 - accuracy: 0.6917 - val_loss: 1.0914 - val_accuracy: 0.6291
# Epoch 12/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.8406 - accuracy: 0.7006 - val_loss: 1.1075 - val_accuracy: 0.6291
# Epoch 13/100
# 313/313 [==============================] - 6s 21ms/step - loss: 0.8131 - accuracy: 0.7116 - val_loss: 1.1064 - val_accuracy: 0.6324
# Epoch 14/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.7868 - accuracy: 0.7203 - val_loss: 1.1316 - val_accuracy: 0.6266
# Epoch 15/100
# 313/313 [==============================] - 6s 21ms/step - loss: 0.7666 - accuracy: 0.7269 - val_loss: 1.1359 - val_accuracy: 0.6313
# Epoch 16/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.7363 - accuracy: 0.7347 - val_loss: 1.1353 - val_accuracy: 0.6287
# Epoch 17/100
# 313/313 [==============================] - 6s 21ms/step - loss: 0.7190 - accuracy: 0.7420 - val_loss: 1.1651 - val_accuracy: 0.6258
# Epoch 18/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.6947 - accuracy: 0.7535 - val_loss: 1.2070 - val_accuracy: 0.6266
# Epoch 19/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.6659 - accuracy: 0.7624 - val_loss: 1.2046 - val_accuracy: 0.6244
# Epoch 20/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.6546 - accuracy: 0.7659 - val_loss: 1.2025 - val_accuracy: 0.6207
# Epoch 21/100
# 313/313 [==============================] - 6s 20ms/step - loss: 0.6302 - accuracy: 0.7719 - val_loss: 1.2373 - val_accuracy: 0.6208

# %%
# Show results
results = model.evaluate(x_test, y_test)
print(results)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 1.2293 - accuracy: 0.6191
# [1.229333758354187, 0.6190999746322632]

# %%
# Plot results
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# Show model layers
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

conv_base.trainable = True


layer_list = ["block4_conv1", "block5_conv1"]
for layer in conv_base.layers:
    if layer.name in layer_list:
        set_trainable = True
    else:
        layer.trainable = False


modified_model = Sequential([
   conv_base,
   Flatten(),
   Dense(256, activation="relu"),
   Dense(10, activation="softmax"),
])

# %%
# Compile and training model
modified_model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy'])


history = modified_model.fit(
    x_train, y_train, epochs=20, verbose=1, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/20
# 313/313 [==============================] - 14s 33ms/step - loss: 1.0439 - accuracy: 0.6339 - val_loss: 0.8277 - val_accuracy: 0.7090
# Epoch 2/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.7017 - accuracy: 0.7555 - val_loss: 0.6883 - val_accuracy: 0.7594
# Epoch 3/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.5971 - accuracy: 0.7923 - val_loss: 0.6712 - val_accuracy: 0.7656
# Epoch 4/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.5201 - accuracy: 0.8188 - val_loss: 0.6630 - val_accuracy: 0.7756
# Epoch 5/20
# 313/313 [==============================] - 10s 30ms/step - loss: 0.4512 - accuracy: 0.8444 - val_loss: 0.6310 - val_accuracy: 0.7832
# Epoch 6/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.3967 - accuracy: 0.8624 - val_loss: 0.6532 - val_accuracy: 0.7789
# Epoch 7/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.3380 - accuracy: 0.8842 - val_loss: 0.5862 - val_accuracy: 0.7967
# Epoch 8/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.2797 - accuracy: 0.9042 - val_loss: 0.6239 - val_accuracy: 0.7936
# Epoch 9/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.2400 - accuracy: 0.9195 - val_loss: 0.6411 - val_accuracy: 0.7994
# Epoch 10/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.1967 - accuracy: 0.9347 - val_loss: 0.6297 - val_accuracy: 0.8074
# Epoch 11/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.1606 - accuracy: 0.9470 - val_loss: 0.6796 - val_accuracy: 0.8040
# Epoch 12/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.1274 - accuracy: 0.9593 - val_loss: 0.6848 - val_accuracy: 0.8031
# Epoch 13/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.1038 - accuracy: 0.9693 - val_loss: 0.7459 - val_accuracy: 0.7999
# Epoch 14/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0715 - accuracy: 0.9798 - val_loss: 0.7983 - val_accuracy: 0.8022
# Epoch 15/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0648 - accuracy: 0.9820 - val_loss: 0.8126 - val_accuracy: 0.8002
# Epoch 16/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0560 - accuracy: 0.9844 - val_loss: 0.8403 - val_accuracy: 0.8020
# Epoch 17/20
# 313/313 [==============================] - 10s 30ms/step - loss: 0.0456 - accuracy: 0.9877 - val_loss: 0.8497 - val_accuracy: 0.7997
# Epoch 18/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0371 - accuracy: 0.9904 - val_loss: 0.8833 - val_accuracy: 0.8054
# Epoch 19/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0254 - accuracy: 0.9939 - val_loss: 0.9518 - val_accuracy: 0.8078
# Epoch 20/20
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0256 - accuracy: 0.9941 - val_loss: 1.0012 - val_accuracy: 0.7987

# %%
# Show results
results = modified_model.evaluate(x_test, y_test)
print(f'відсоток вірних відповідей - {round(results[1] * 100, 1)}%')
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 1.0608 - accuracy: 0.7974
# відсоток вірних відповідей - 79.7%

# %%
# Plot results
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# Save model
#modified_model.save("weights.h5")
